# %%
import math

# %%
Lxy = 142.245
Lz = 10

Nx = 51
Ny = 51
Nz = 1

dx = Lxy/Nx
dy = Lxy/Ny
dz = Lz/Nz

dv = dx*dy*dz
dv
# Out:
# 77.79177249134948

# %%
re = math.sqrt(dv/math.pi)
re
# Out:
# 4.9761320569049206

# %%
K = 3.0e-13
WI = 2 * math.pi * K * 2.789117647 / (math.log(10.0))
